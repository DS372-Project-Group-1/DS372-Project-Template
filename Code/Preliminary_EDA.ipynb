# %%
import pandas as pd

# %%
wildfires = pd.read_csv('https://raw.githubusercontent.com/DS372-Project-Group-1/DS372-Project-Template/main/Datasets/raw-datasets/Fire_Disturbance_Point.csv')

# %%
pm25 = pd.read_csv('https://raw.githubusercontent.com/DS372-Project-Group-1/DS372-Project-Template/main/Datasets/raw-datasets/PM25.csv')

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/LamaEmran/Data/main/All_Cities_Weather_Final.csv')

# %%
integrated_data = pd.read_csv('https://github.com/MajdBa7r/AQI/raw/main/ontario_wildfire_weather_pm_2017_2024_2.csv')

# %% [markdown]
# ## **Wildfires:**

# %%
wildfires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65006 entries, 0 to 65005
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   X                            65006 non-null  float64
#  1   Y                            65006 non-null  float64
#  2   OGF_ID                       65006 non-null  int64
#  3   FIRE_DISTURBANCE_AREA_IDENT  65006 non-null  object
#  4   FIRE_TYPE_CODE               65006 non-null  object
#  5   FIRE_YEAR                    65006 non-null  int64
#  6   FIRE_GENERAL_CAUSE_CODE      64934 non-null  object
#  7   FIRE_WEATHER_INDEX           65006 non-null  float64
#  8   FIRE_RESPONSE_OBJ_CODE       40935 non-null  object
#  9   FIRE_START_DATE              64957 non-null  object
#  10  FIRE_OUT_DATE                63804 non-null  object
#  11  FIRE_FINAL_SIZE              65006 non-null  float64
#  12  BUSINESS_EFFECTIVE_DATE      17152 non-null  object
# ...

# %%
wildfires.describe()
# Out:
#                   X             Y        OGF_ID     FIRE_YEAR  \
# count  65006.000000  65006.000000  6.500600e+04  65006.000000
# mean     -86.035337     48.495867  1.154098e+08   1995.243408
# std        5.859205      2.320584  4.885665e+07     13.328450
# min      -95.162900     41.740100  4.312876e+07   1976.000000
# 25%      -91.682775     46.461000  1.069561e+08   1984.000000
# 50%      -85.775850     48.698350  1.069723e+08   1994.000000
# 75%      -80.687400     50.094100  1.069906e+08   2005.000000
# max      -74.618700     56.545500  3.209617e+08   2024.000000
#
#        FIRE_WEATHER_INDEX  FIRE_FINAL_SIZE       OBJECTID
# count        65006.000000     65006.000000   65006.000000
# mean            11.423224       152.696039  392502.640156
# std              9.086919      2362.562487  290459.543330
# min              0.000000         0.000000       1.000000
# 25%              4.000000         0.100000  119349.000000
# ...

# %% [markdown]
# ## **Weather:**

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168648 entries, 0 to 168647
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   time                               168648 non-null  object
#  1   precipitation_sum (mm)             168648 non-null  float64
#  2   rain_sum (mm)                      168648 non-null  float64
#  3   snowfall_sum (cm)                  168648 non-null  float64
#  4   relative_humidity_2m_mean (%)      168648 non-null  int64
#  5   relative_humidity_2m_max (%)       168648 non-null  int64
#  6   relative_humidity_2m_min (%)       168648 non-null  int64
#  7   dew_point_2m_mean (°C)             168648 non-null  float64
#  8   shortwave_radiation_sum (MJ/m²)    168648 non-null  float64
#  9   sunshine_duration (s)              168646 non-null  float64
#  10  temperature_2m_mean (°C)           168647 non-null  float64
# ...

# %%
weather.describe()
# Out:
#        precipitation_sum (mm)  rain_sum (mm)  snowfall_sum (cm)  \
# count           168648.000000  168648.000000      168648.000000
# mean                 2.468498       1.894819           0.410133
# std                  5.150235       4.823435           1.398219
# min                  0.000000       0.000000           0.000000
# 25%                  0.000000       0.000000           0.000000
# 50%                  0.200000       0.000000           0.000000
# 75%                  2.500000       1.100000           0.000000
# max                103.400000     103.400000          28.840000
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_max (%)  \
# count                  168648.000000                 168648.000000
# mean                       71.996508                     87.914206
# std                        13.504867                     11.612555
# min                         2.000000                      4.000000
# ...

# %% [markdown]
# ## **PM2.5:**

# %%
pm25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216228 entries, 0 to 216227
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   city    216228 non-null  object
#  1   date    216228 non-null  object
#  2   lat     216228 non-null  float64
#  3   lon     216228 non-null  float64
#  4   pm25    216228 non-null  float64
#  5   year    216228 non-null  int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 9.9+ MB

# %%
print(pm25.describe())
# Out:
#                  lat            lon           pm25           year
# count  216228.000000  216228.000000  216228.000000  216228.000000
# mean       46.023847     -80.722172       4.980391    2020.501027
# std         2.125295       4.523612       7.028086       2.291442
# min        42.283500     -94.292200       0.001337    2017.000000
# 25%        44.589100     -81.843900       1.361134    2019.000000
# 50%        45.360750     -79.755350       3.345392    2020.500000
# 75%        47.168900     -77.445900       6.855265    2023.000000
# max        52.106900     -74.618700    1417.456644    2024.000000

# %% [markdown]
# ## **Fully Integrated Data:**

# %%
integrated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139502 entries, 0 to 139501
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   city                               139502 non-null  object
#  1   date                               139502 non-null  object
#  2   lat                                139502 non-null  float64
#  3   lon                                139502 non-null  float64
#  4   pm25                               139502 non-null  float64
#  5   year                               139502 non-null  int64
#  6   precipitation_sum (mm)             139502 non-null  float64
#  7   rain_sum (mm)                      139502 non-null  float64
#  8   snowfall_sum (cm)                  139502 non-null  float64
#  9   relative_humidity_2m_mean (%)      139502 non-null  float64
#  10  relative_humidity_2m_max (%)       139502 non-null  float64
# ...

# %%
integrated_data.describe()
# Out:
#                  lat            lon           pm25           year  \
# count  139502.000000  139502.000000  139502.000000  139502.000000
# mean       46.996808     -82.018417       4.099721    2020.491040
# std         2.033204       4.823376       7.633472       2.290909
# min        44.485500     -94.292200       0.001337    2017.000000
# 25%        45.200100     -83.717000       0.989316    2018.000000
# 50%        46.352200     -79.914700       2.503802    2020.000000
# 75%        48.684400     -78.460600       5.502272    2022.000000
# max        52.106900     -76.527800    1417.456644    2024.000000
#
#        precipitation_sum (mm)  rain_sum (mm)  snowfall_sum (cm)  \
# count           139502.000000  139502.000000      139502.000000
# mean                 2.551007       1.921572           0.442133
# std                  5.206069       4.863637           1.459891
# min                  0.000000       0.000000           0.000000
# ...
