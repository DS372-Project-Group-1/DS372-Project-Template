# %% [markdown]
# # Integration File
# In this integration file, we performed the initial merging of all data sources with only minimal preprocessing. First, we linked the location dataset with the wildfire dataset to assign each fire event to its correct city, ensuring that wildfire records can later be aligned with weather and air-quality data. Next, we merged the weather dataset with the PM2.5 dataset, since they share identical city names and the same daily time range. After preparing both parts, we combined the integrated weather–PM data with the wildfire data to form a single unified dataset. At this stage, a few issues remain—such as duplicates, missing values, and potential outliers—which will be handled in the subsequent cleaning and feature-engineering steps.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# # WildFire

# %%
fires=pd.read_csv('https://github.com/MajdBa7r/AQI/raw/main/Fire_Disturbance_Point%20(1).csv')

# %%
fires
# Out:
#              X        Y     OGF_ID FIRE_DISTURBANCE_AREA_IDENT FIRE_TYPE_CODE  \
# 0     -88.0381  49.0228   43129190                        NIP2            IFR
# 1     -86.7287  49.8475   43129191                       NIP20            IFR
# 2     -88.0725  50.2296   43129192                       NIP21            IFR
# 3     -88.5994  53.4975   43129193                       NIP22            IFR
# 4     -87.9607  50.2486   43129194                       NIP23            IFR
# ...        ...      ...        ...                         ...            ...
# 65001 -90.0352  51.4709  320961613                        SLK9            IFR
# 65002 -93.2444  52.4091  320961347                        RED3            IFR
# 65003 -85.6377  48.6897  320961181                       WAW15            IFR
# 65004 -94.5996  49.8023  320961430                        KEN9            IFR
# 65005 -77.9270  46.2124  320961363                        PEM2            IFR
#
#        FIRE_YEAR FIRE_GENERAL_CAUSE_CODE  FIRE_WEATHER_INDEX  \
# 0           2003                     RWY            0.000000
# 1           2003                     UNK           16.200001
# 2           2003                     RWY           19.200001
# 3           2003                     REC           26.900000
# 4           2003                     RWY           19.200001
# ...          ...                     ...                 ...
# 65001       2024                     LTG           14.000000
# 65002       2024                     LTG            8.000000
# 65003       2024                     UNK            0.000000
# 65004       2024                     UNK            0.000000
# 65005       2024                     REC            9.000000
#
#       FIRE_RESPONSE_OBJ_CODE         FIRE_START_DATE           FIRE_OUT_DATE  \
# 0                        SUP  2003/04/13 00:00:00+00  2003/04/14 00:00:00+00
# 1                        SUP  2003/05/27 00:00:00+00  2003/05/27 00:00:00+00
# 2                        SUP  2003/05/25 00:00:00+00  2003/05/25 00:00:00+00
# 3                        SUP  2003/05/27 00:00:00+00  2003/05/28 00:00:00+00
# 4                        SUP  2003/05/25 00:00:00+00  2003/05/25 00:00:00+00
# ...                      ...                     ...                     ...
# 65001                    FUL  2024/07/07 00:00:00+00  2024/07/09 00:00:00+00
# 65002                    FUL  2024/07/06 00:00:00+00  2024/07/12 00:00:00+00
# 65003                    FUL  2024/08/28 00:00:00+00  2024/08/28 00:00:00+00
# 65004                    FUL  2024/06/03 00:00:00+00  2024/06/04 00:00:00+00
# 65005                    FUL  2024/05/16 00:00:00+00  2024/05/16 00:00:00+00
#
#        FIRE_FINAL_SIZE BUSINESS_EFFECTIVE_DATE GEOMETRY_UPDATE_DATETIME  \
# 0                  1.5  2004/06/16 00:00:00+00                      NaN
# 1                  0.1  2004/06/16 00:00:00+00                      NaN
# 2                 15.0  2004/06/16 00:00:00+00                      NaN
# 3                  0.4  2004/06/16 00:00:00+00                      NaN
# 4                  0.2  2004/06/16 00:00:00+00                      NaN
# ...                ...                     ...                      ...
# 65001              0.6                     NaN   2025/02/21 11:34:46+00
# 65002              4.8                     NaN   2025/02/21 11:34:46+00
# 65003              0.1                     NaN   2025/02/21 11:34:47+00
# 65004              0.1                     NaN   2025/02/21 11:34:42+00
# 65005              0.1                     NaN   2025/02/21 11:34:44+00
#
#            EFFECTIVE_DATETIME         SYSTEM_DATETIME  OBJECTID
# 0      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00         1
# 1      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00         2
# 2      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00         3
# 3      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00         4
# 4      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00         5
# ...                       ...                     ...       ...
# 65001  2025/02/21 10:58:59+00  2025/02/21 22:19:59+00    938657
# 65002  2025/02/21 10:58:33+00  2025/02/21 22:19:59+00    938673
# 65003  2025/02/21 10:58:16+00  2025/02/21 22:19:59+00    938689
# 65004  2025/02/21 10:58:42+00  2025/02/21 22:19:59+00    938705
# 65005  2025/02/21 10:58:35+00  2025/02/21 22:19:59+00    938721
#
# [65006 rows x 17 columns]

# %%
fires['longitude']=fires['X']
fires['latitude']=fires['Y']
fires.drop(['X','Y'],axis=1,inplace=True)#only for unifying names

# %%
locations=pd.read_csv('https://github.com/LamaEmran/Data/raw/main/ontario_wildfires_refined.csv')#locations file

# %%
locations
# Out:
#        longitude  latitude Province City / Town
# 0       -88.0381   49.0228  Ontario  Greenstone
# 1       -86.7287   49.8475  Ontario  Greenstone
# 2       -88.0725   50.2296  Ontario  Greenstone
# 3       -88.5994   53.4975  Ontario  Greenstone
# 4       -87.9607   50.2486  Ontario  Greenstone
# ...          ...       ...      ...         ...
# 58260   -84.7862   48.4938  Ontario  Hornepayne
# 58261   -90.0352   51.4709  Ontario    Atikokan
# 58262   -93.2444   52.4091  Ontario    Red Lake
# 58263   -85.6377   48.6897  Ontario    Marathon
# 58264   -77.9270   46.2124  Ontario  Deep River
#
# [58265 rows x 4 columns]

# %%
g1=gpd.GeoDataFrame(fires, geometry=gpd.points_from_xy(fires['longitude'], fires['latitude']))
g2=gpd.GeoDataFrame(locations, geometry=gpd.points_from_xy(locations['longitude'] , locations['latitude']))

# %%
g1.crs = "EPSG:4326"
g2.crs = "EPSG:4326"
g1_meters = g1.to_crs("EPSG:3347")#EPSG:3347 is the Statistics Canada Lambert projection (units = meters)
g2_meters = g2.to_crs("EPSG:3347")

# %% [markdown]
# We converted both datasets from geographic coordinates (EPSG:4326) to a projected coordinate system (EPSG:3347) so that distances are measured in meters. This is necessary because spatial operations like sjoin_nearest and max_distance require accurate linear distances, which cannot be computed correctly in latitude–longitude

# %% [markdown]
# If we don’t convert to a projected coordinate system, distance calculations would be inaccurate because latitude–longitude degrees are not uniform in length. As a result, spatial joins using max_distance or nearest-neighbor methods **could assign fires to the wrong cities or fail to find nearby points.**

# %%
merged = g2_meters.sjoin_nearest(g1_meters, how='inner', max_distance=100000)

# %% [markdown]
# We used sjoin_nearest instead of an exact merge because wildfire points rarely match location coordinates exactly, so nearest-neighbor spatial joining is the correct way to assign each fire to the closest city based on geographic distance.

# %%
merged.duplicated().sum()
# Out:
# np.int64(30378)

# %%
merged.drop_duplicates(inplace=True)

# %% [markdown]
# A nearest-neighbor spatial join (sjoin_nearest) produces duplicates because it matches each point to the closest geographic feature rather than enforcing a one-to-one relationship. When multiple observations share the same nearest wildfire point, that wildfire record is repeated for each observation. Since the method is based purely on spatial proximity—not on unique relational keys like city or date—duplicate matches naturally occur.

# %%
merged
# Out:
#        longitude_left  latitude_left Province City / Town  \
# 0            -88.0381        49.0228  Ontario  Greenstone
# 0            -88.0381        49.0228  Ontario  Greenstone
# 1            -86.7287        49.8475  Ontario  Greenstone
# 2            -88.0725        50.2296  Ontario  Greenstone
# 3            -88.5994        53.4975  Ontario  Greenstone
# ...               ...            ...      ...         ...
# 58260        -84.7862        48.4938  Ontario  Hornepayne
# 58261        -90.0352        51.4709  Ontario    Atikokan
# 58262        -93.2444        52.4091  Ontario    Red Lake
# 58263        -85.6377        48.6897  Ontario    Marathon
# 58264        -77.9270        46.2124  Ontario  Deep River
#
#                               geometry  index_right     OGF_ID  \
# 0      POINT (6479821.435 1439947.521)           42   43129232
# 0      POINT (6479821.435 1439947.521)            0   43129190
# 1      POINT (6567952.169 1537962.442)            1   43129191
# 2      POINT (6469327.381 1573463.803)            2   43129192
# 3      POINT (6413478.976 1930876.384)            3   43129193
# ...                                ...          ...        ...
# 58260  POINT (6723280.643 1401795.575)        65000  320961228
# 58261  POINT (6326116.319 1704402.146)        65001  320961613
# 58262  POINT (6107360.001 1806899.561)        65002  320961347
# 58263  POINT (6658432.456 1416924.865)        65003  320961181
# 58264    POINT (7279611.22 1236062.11)        65005  320961363
#
#       FIRE_DISTURBANCE_AREA_IDENT FIRE_TYPE_CODE  FIRE_YEAR  ...  \
# 0                           NIP60            IFR       2003  ...
# 0                            NIP2            IFR       2003  ...
# 1                           NIP20            IFR       2003  ...
# 2                           NIP21            IFR       2003  ...
# 3                           NIP22            IFR       2003  ...
# ...                           ...            ...        ...  ...
# 58260                       WAW13            IFR       2024  ...
# 58261                        SLK9            IFR       2024  ...
# 58262                        RED3            IFR       2024  ...
# 58263                       WAW15            IFR       2024  ...
# 58264                        PEM2            IFR       2024  ...
#
#               FIRE_START_DATE           FIRE_OUT_DATE FIRE_FINAL_SIZE  \
# 0      2003/06/29 00:00:00+00  2003/06/29 00:00:00+00             0.3
# 0      2003/04/13 00:00:00+00  2003/04/14 00:00:00+00             1.5
# 1      2003/05/27 00:00:00+00  2003/05/27 00:00:00+00             0.1
# 2      2003/05/25 00:00:00+00  2003/05/25 00:00:00+00            15.0
# 3      2003/05/27 00:00:00+00  2003/05/28 00:00:00+00             0.4
# ...                       ...                     ...             ...
# 58260  2024/08/21 00:00:00+00  2024/09/13 00:00:00+00            29.5
# 58261  2024/07/07 00:00:00+00  2024/07/09 00:00:00+00             0.6
# 58262  2024/07/06 00:00:00+00  2024/07/12 00:00:00+00             4.8
# 58263  2024/08/28 00:00:00+00  2024/08/28 00:00:00+00             0.1
# 58264  2024/05/16 00:00:00+00  2024/05/16 00:00:00+00             0.1
#
#       BUSINESS_EFFECTIVE_DATE GEOMETRY_UPDATE_DATETIME  \
# 0      2004/06/16 00:00:00+00                      NaN
# 0      2004/06/16 00:00:00+00                      NaN
# 1      2004/06/16 00:00:00+00                      NaN
# 2      2004/06/16 00:00:00+00                      NaN
# 3      2004/06/16 00:00:00+00                      NaN
# ...                       ...                      ...
# 58260                     NaN   2025/02/21 11:34:47+00
# 58261                     NaN   2025/02/21 11:34:46+00
# 58262                     NaN   2025/02/21 11:34:46+00
# 58263                     NaN   2025/02/21 11:34:47+00
# 58264                     NaN   2025/02/21 11:34:44+00
#
#            EFFECTIVE_DATETIME         SYSTEM_DATETIME OBJECTID  \
# 0      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00       43
# 0      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00        1
# 1      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00        2
# 2      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00        3
# 3      2004/06/16 00:00:00+00  2005/04/22 08:35:11+00        4
# ...                       ...                     ...      ...
# 58260  2025/02/21 10:58:21+00  2025/02/21 22:19:59+00   938641
# 58261  2025/02/21 10:58:59+00  2025/02/21 22:19:59+00   938657
# 58262  2025/02/21 10:58:33+00  2025/02/21 22:19:59+00   938673
# 58263  2025/02/21 10:58:16+00  2025/02/21 22:19:59+00   938689
# 58264  2025/02/21 10:58:35+00  2025/02/21 22:19:59+00   938721
#
#       longitude_right latitude_right
# 0            -88.0381        49.0228
# 0            -88.0381        49.0228
# 1            -86.7287        49.8475
# 2            -88.0725        50.2296
# 3            -88.5994        53.4975
# ...               ...            ...
# 58260        -84.7862        48.4938
# 58261        -90.0352        51.4709
# 58262        -93.2444        52.4091
# 58263        -85.6377        48.6897
# 58264        -77.9270        46.2124
#
# [58265 rows x 23 columns]

# %%
merged['City / Town'].value_counts().shape
# Out:
# (73,)

# %%
merged['Province'].value_counts().shape
# Out:
# (1,)

# %%
y=merged[merged.FIRE_YEAR.isin([2017,2018,2019,2020,2021,2022,2023,2024])].copy() #filter the merged wildfire dataset to keep only records from years 2017 to 2024

# %%
y['City / Town'].value_counts().shape
# Out:
# (47,)

# %%
city_names = y['City / Town'].unique()

# %%
city_names
# Out:
# array(['Atikokan', 'Red Lake', 'Thunder Bay', 'Dryden', 'Greenstone',
#        'Ear Falls', 'Hornepayne', 'Kapuskasing', 'Temiskaming Shores',
#        'Hearst', 'Sault Ste. Marie', 'Deep River', 'Rayside-Balfour',
#        'Greater Sudbury', 'Marathon', 'Espanola', 'Pembroke',
#        'Elliot Lake', 'Fort Frances', 'Iroquois Falls', 'Englehart',
#        'South River', 'Kirkland Lake', 'Neebing', 'Huntsville', 'Mattawa',
#        'Peterborough', 'Timmins', 'Parry Sound', 'Gravenhurst', 'Midland',
#        'North Bay', 'Bancroft', 'Renfrew', 'Skatepark', 'Omemee',
#        'Thessalon', 'Tobermory', 'Powassan', 'Perth', 'Greater Napanee',
#        'Little Current', 'Bracebridge', 'Belleville', 'Arnprior',
#        'Petawawa', 'Orillia'], dtype=object)

# %%
y.to_csv('ontario_wildfires_from2017to2024.csv',index=False)

# %%
#this is only to check against the previous integration method we applied
NF= pd.read_csv('https://raw.githubusercontent.com/frxqie/Data_Eng_Data/main/ontario_wildfires_prepped.csv')
NF=NF[NF.FIRE_YEAR.isin([2017,2018,2019,2020,2021,2022,2023,2024])]

# %%
NF['City / Town'].value_counts().shape
# Out:
# (46,)

# %%
y['City / Town'].value_counts().shape
# Out:
# (47,)

# %%
cities1 = set(y['City / Town'].str.strip().str.lower())
cities2 = set(NF['City / Town'].str.strip().str.lower())

common = cities1 & cities2
missing_from_df2 = cities1 - cities2
missing_from_df1 = cities2 - cities1

print("Common cities:", len(common))
print("Cities missing from Naser and Farah cities:", missing_from_df2)
print("Cities missing from our cities:", missing_from_df1)
# Out:
# Common cities: 46
# Cities missing from Naser and Farah cities: {'skatepark'}
# Cities missing from our cities: set()

# %%
y[y['City / Town'].str.lower().str.contains('skatepark')]
# Out:
#        longitude_left  latitude_left Province City / Town  \
# 50946        -77.0506        44.8843  Ontario   Skatepark
# 51142        -76.9863        44.6325  Ontario   Skatepark
# 51667        -76.8204        44.6920  Ontario   Skatepark
# 52002        -76.7849        44.5344  Ontario   Skatepark
# 53736        -76.9254        44.7786  Ontario   Skatepark
#
#                               geometry  index_right     OGF_ID  \
# 50946  POINT (7380871.045 1105644.867)        56962  125435708
# 51142  POINT (7392509.675 1079114.897)        57187  125435897
# 51667  POINT (7403978.245 1088792.775)        57775  125434978
# 52002  POINT (7410958.828 1072113.285)        58160  127799207
# 53736  POINT (7393450.161 1096346.632)        60140  165649128
#
#       FIRE_DISTURBANCE_AREA_IDENT FIRE_TYPE_CODE  FIRE_YEAR  ...  \
# 50946                       BAN15            IFR       2018  ...
# 51142                        PET3            IFR       2018  ...
# 51667                        PET1            IFR       2018  ...
# 52002                        PET3            IFR       2019  ...
# 53736                        PET1            IFR       2021  ...
#
#               FIRE_START_DATE           FIRE_OUT_DATE FIRE_FINAL_SIZE  \
# 50946  2018/07/05 00:00:00+00  2018/07/09 00:00:00+00             0.1
# 51142  2018/07/12 00:00:00+00  2018/07/20 00:00:00+00             4.3
# 51667  2018/05/14 00:00:00+00  2018/05/15 00:00:00+00             0.8
# 52002  2019/08/01 00:00:00+00  2019/08/27 00:00:00+00             4.2
# 53736  2021/06/13 00:00:00+00  2021/06/22 00:00:00+00             6.0
#
#       BUSINESS_EFFECTIVE_DATE GEOMETRY_UPDATE_DATETIME  \
# 50946  2019/03/22 11:01:56+00   2019/03/22 11:06:23+00
# 51142  2019/03/22 11:01:56+00   2019/03/22 11:06:26+00
# 51667  2019/03/22 11:01:56+00   2019/03/22 11:06:14+00
# 52002  2020/02/20 14:45:15+00   2020/02/20 14:48:49+00
# 53736  2022/03/07 11:44:04+00   2022/03/07 11:52:58+00
#
#            EFFECTIVE_DATETIME         SYSTEM_DATETIME OBJECTID  \
# 50946  2019/03/22 11:02:15+00  2019/03/22 21:57:15+00   771633
# 51142  2019/03/22 11:02:19+00  2019/03/22 21:57:15+00   775233
# 51667  2019/03/22 11:02:16+00  2019/03/22 21:57:15+00   784641
# 52002  2020/02/20 14:45:31+00  2020/02/20 21:47:15+00   791041
# 53736  2022/03/07 11:44:27+00  2022/03/09 04:09:25+00   823041
#
#       longitude_right latitude_right
# 50946        -77.0506        44.8843
# 51142        -76.9863        44.6325
# 51667        -76.8204        44.6920
# 52002        -76.7849        44.5344
# 53736        -76.9254        44.7786
#
# [5 rows x 23 columns]

# %%
y['City / Town'] = y['City / Town'].replace('Skatepark', 'Frontenac')

# %% [markdown]
# Manually checked the locations of these entries on maps and corrected them accordingly

# %%
y["FIRE_START_DATE"] = pd.to_datetime(
    y["FIRE_START_DATE"],
    errors="coerce"
).dt.date

y["FIRE_OUT_DATE"] = pd.to_datetime(
    y["FIRE_OUT_DATE"],
    errors="coerce"
).dt.date
#This ensures consistent date handling

# %%
y['date']=y['FIRE_START_DATE']
y['city']=y['City / Town']

# %%
y['city'] = y['city'].str.strip().str.lower()
y['date'] = pd.to_datetime(y['date'])

# %%
y.columns
# Out:
# Index(['longitude_left', 'latitude_left', 'Province', 'City / Town',
#        'geometry', 'index_right', 'OGF_ID', 'FIRE_DISTURBANCE_AREA_IDENT',
#        'FIRE_TYPE_CODE', 'FIRE_YEAR', 'FIRE_GENERAL_CAUSE_CODE',
#        'FIRE_WEATHER_INDEX', 'FIRE_RESPONSE_OBJ_CODE', 'FIRE_START_DATE',
#        'FIRE_OUT_DATE', 'FIRE_FINAL_SIZE', 'BUSINESS_EFFECTIVE_DATE',
#        'GEOMETRY_UPDATE_DATETIME', 'EFFECTIVE_DATETIME', 'SYSTEM_DATETIME',
#        'OBJECTID', 'longitude_right', 'latitude_right', 'date', 'city'],
#       dtype='object')

# %%
y[['date','city']].duplicated().sum()
# Out:
# np.int64(2168)

# %% [markdown]
# Duplicates appear when merging by date and city because multiple wildfire events can occur in the same city on the same day. Each fire becomes a separate row, so when the dataset is merged with daily city-level data, one day can match multiple fire records. Aggregating the wildfire dataset by date and city (summing fire size or averaging fire indices) resolves this by producing a single consolidated record per day per city.

# %%
mask =y['FIRE_OUT_DATE'] < y['FIRE_START_DATE']
y.loc[mask, ['FIRE_START_DATE', 'FIRE_OUT_DATE']]=y.loc[mask, ['FIRE_OUT_DATE', 'FIRE_START_DATE']].values

# %% [markdown]
# # Weather and PM

# %%
weather_url = "https://github.com/LamaEmran/Data/raw/main/All_Cities_Weather_Final.csv"
weather = pd.read_csv(weather_url)
aqi = pd.read_csv('https://github.com/MajdBa7r/AQI/raw/main/PM2.5.csv')

# %% [markdown]
# These files have already been prepared for integration in other notebooks

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270322 entries, 0 to 270321
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   time                               270322 non-null  object
#  1   precipitation_sum (mm)             270322 non-null  float64
#  2   rain_sum (mm)                      270322 non-null  float64
#  3   snowfall_sum (cm)                  270322 non-null  float64
#  4   relative_humidity_2m_mean (%)      270322 non-null  int64
#  5   relative_humidity_2m_max (%)       270322 non-null  int64
#  6   relative_humidity_2m_min (%)       270322 non-null  int64
#  7   dew_point_2m_mean (°C)             270322 non-null  float64
#  8   shortwave_radiation_sum (MJ/m²)    270322 non-null  float64
#  9   sunshine_duration (s)              270321 non-null  float64
#  10  temperature_2m_mean (°C)           270322 non-null  float64
#  11  temperature_2m_max (°C)            270322 non-null  float64
#  12  temperature_2m_min (°C)            270322 non-null  float64
#  13  wind_speed_10m_mean (km/h)         270322 non-null  float64
#  14  wind_speed_10m_max (km/h)          270322 non-null  float64
#  15  winddirection_10m_dominant (°)     270322 non-null  int64
#  16  vapour_pressure_deficit_max (kPa)  270322 non-null  float64
#  17  et0_fao_evapotranspiration (mm)    270322 non-null  float64
#  18  City                               270322 non-null  object
# dtypes: float64(13), int64(4), object(2)
# memory usage: 39.2+ MB

# %%
weather['city']=weather['City']
weather['date']=weather['time']

# %%
weather
# Out:
#               time  precipitation_sum (mm)  rain_sum (mm)  snowfall_sum (cm)  \
# 0       2015-01-01                     0.0            0.0               0.00
# 1       2015-01-02                     0.0            0.0               0.00
# 2       2015-01-03                     2.7            0.0               2.10
# 3       2015-01-04                     0.0            0.0               0.00
# 4       2015-01-05                     0.0            0.0               0.00
# ...            ...                     ...            ...                ...
# 270317  2024-12-27                     0.0            0.0               0.00
# 270318  2024-12-28                     1.6            1.6               0.00
# 270319  2024-12-29                    21.4           21.4               0.00
# 270320  2024-12-30                    15.4            8.6               4.76
# 270321  2024-12-31                     0.6            0.1               0.35
#
#         relative_humidity_2m_mean (%)  relative_humidity_2m_max (%)  \
# 0                                  47                            57
# 1                                  50                            61
# 2                                  79                            89
# 3                                  60                            67
# 4                                  48                            66
# ...                               ...                           ...
# 270317                             88                            90
# 270318                             91                            99
# 270319                             97                            99
# 270320                             98                           100
# 270321                             93                            97
#
#         relative_humidity_2m_min (%)  dew_point_2m_mean (°C)  \
# 0                                 24                   -13.0
# 1                                 34                    -9.0
# 2                                 65                    -7.1
# 3                                 43                   -13.9
# 4                                 30                   -13.1
# ...                              ...                     ...
# 270317                            84                    -1.1
# 270318                            79                     4.3
# 270319                            92                     3.7
# 270320                            93                     2.8
# 270321                            89                    -1.1
#
#         shortwave_radiation_sum (MJ/m²)  sunshine_duration (s)  ...  \
# 0                                  7.36               27754.97  ...
# 1                                  4.78               14817.90  ...
# 2                                  4.19               15319.11  ...
# 3                                  7.63               27817.25  ...
# 4                                  5.57               18155.53  ...
# ...                                 ...                    ...  ...
# 270317                             4.33               11162.59  ...
# 270318                             4.73               19087.58  ...
# 270319                             0.69                   0.00  ...
# 270320                             1.32                   0.00  ...
# 270321                             2.64                   0.00  ...
#
#         temperature_2m_max (°C)  temperature_2m_min (°C)  \
# 0                           5.8                     -9.7
# 1                           7.4                     -5.4
# 2                          -1.5                     -8.0
# 3                           1.5                    -13.0
# 4                           4.0                    -12.9
# ...                         ...                      ...
# 270317                      2.6                     -0.9
# 270318                     11.2                      1.6
# 270319                      6.7                      2.1
# 270320                      7.8                      0.7
# 270321                      1.7                     -2.2
#
#         wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                              6.1                        8.4
# 1                              4.6                        7.6
# 2                              6.1                        7.9
# 3                              5.9                        7.2
# 4                              5.1                        7.9
# ...                            ...                        ...
# 270317                        20.8                       24.3
# 270318                        23.4                       30.8
# 270319                        12.4                       20.3
# 270320                        22.6                       31.0
# 270321                        10.2                       19.1
#
#         winddirection_10m_dominant (°)  vapour_pressure_deficit_max (kPa)  \
# 0                                    9                               0.70
# 1                                   10                               0.68
# 2                                  107                               0.18
# 3                                   17                               0.36
# 4                                  357                               0.57
# ...                                ...                                ...
# 270317                             136                               0.11
# 270318                             174                               0.27
# 270319                              90                               0.08
# 270320                             266                               0.05
# 270321                              11                               0.07
#
#         et0_fao_evapotranspiration (mm)     City     city        date
# 0                                  1.00    Angus    Angus  2015-01-01
# 1                                  0.78    Angus    Angus  2015-01-02
# 2                                  0.39    Angus    Angus  2015-01-03
# 3                                  0.76    Angus    Angus  2015-01-04
# 4                                  0.81    Angus    Angus  2015-01-05
# ...                                 ...      ...      ...         ...
# 270317                             0.44  Wingham  Wingham  2024-12-27
# 270318                             0.57  Wingham  Wingham  2024-12-28
# 270319                             0.16  Wingham  Wingham  2024-12-29
# 270320                             0.14  Wingham  Wingham  2024-12-30
# 270321                             0.26  Wingham  Wingham  2024-12-31
#
# [270322 rows x 21 columns]

# %%
aqi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216228 entries, 0 to 216227
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   city    216228 non-null  object
#  1   date    216228 non-null  object
#  2   lat     216228 non-null  float64
#  3   lon     216228 non-null  float64
#  4   pm25    216228 non-null  float64
#  5   year    216228 non-null  int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 9.9+ MB

# %%
aqi
# Out:
#                 city        date      lat      lon       pm25  year
# 0              Angus  2017-01-01  44.1552 -79.8932  11.076371  2017
# 1           Arnprior  2017-01-01  45.2001 -76.5278   2.090151  2017
# 2           Atikokan  2017-01-01  51.2216 -90.2304   0.128585  2017
# 3           Bancroft  2017-01-01  45.5890 -78.3437   2.089787  2017
# 4             Barrie  2017-01-01  44.4243 -79.7877  10.341466  2017
# ...              ...         ...      ...      ...        ...   ...
# 216223       Timmins  2024-12-31  49.1549 -81.2948   0.055960  2024
# 216224     Tobermory  2024-12-31  45.6419 -81.7172   0.211195  2024
# 216225  Wasaga Beach  2024-12-31  44.4896 -80.0253   0.770121  2024
# 216226       Welland  2024-12-31  42.9326 -79.3149   1.562177  2024
# 216227       Wingham  2024-12-31  44.3033 -81.5578   0.948341  2024
#
# [216228 rows x 6 columns]

# %%
merged2 = aqi.merge(weather, on=['date','city'], how='left')

# %%
merged2['city'] = merged2['city'].replace('Skatepark', 'Frontenac')

# %%
merged2.to_csv('weather and PM.csv',index=False)

# %%
merged2['city'].value_counts().shape
# Out:
# (74,)

# %%
city_names=y['City / Town'].unique()
city_names
# Out:
# array(['Atikokan', 'Red Lake', 'Thunder Bay', 'Dryden', 'Greenstone',
#        'Ear Falls', 'Hornepayne', 'Kapuskasing', 'Temiskaming Shores',
#        'Hearst', 'Sault Ste. Marie', 'Deep River', 'Rayside-Balfour',
#        'Greater Sudbury', 'Marathon', 'Espanola', 'Pembroke',
#        'Elliot Lake', 'Fort Frances', 'Iroquois Falls', 'Englehart',
#        'South River', 'Kirkland Lake', 'Neebing', 'Huntsville', 'Mattawa',
#        'Peterborough', 'Timmins', 'Parry Sound', 'Gravenhurst', 'Midland',
#        'North Bay', 'Bancroft', 'Renfrew', 'Frontenac', 'Omemee',
#        'Thessalon', 'Tobermory', 'Powassan', 'Perth', 'Greater Napanee',
#        'Little Current', 'Bracebridge', 'Belleville', 'Arnprior',
#        'Petawawa', 'Orillia'], dtype=object)

# %%
filtered = merged2[merged2['city'].isin(city_names)].copy()

# %%
filtered['city'].value_counts().shape
# Out:
# (47,)

# %%
filtered.duplicated().sum()
# Out:
# np.int64(0)

# %%
filtered['city'] = filtered['city'].str.strip().str.lower()
filtered['date'] = pd.to_datetime(filtered['date'])

# %% [markdown]
# Standardize city names and convert dates to datetime format for consistent merging and analysis

# %% [markdown]
# # Full Integration

# %%
final_merged = filtered.merge(y,on=['date','city'],how='left',indicator=True)

# %%
final_merged
# Out:
#                       city       date      lat      lon      pm25  year  \
# 0                 arnprior 2017-01-01  45.2001 -76.5278  2.090151  2017
# 1                 atikokan 2017-01-01  51.2216 -90.2304  0.128585  2017
# 2                 bancroft 2017-01-01  45.5890 -78.3437  2.089787  2017
# 3               belleville 2017-01-01  44.4855 -77.4459  4.860390  2017
# 4              bracebridge 2017-01-01  45.1669 -79.2325  6.356419  2017
# ...                    ...        ...      ...      ...       ...   ...
# 139497  temiskaming shores 2024-12-31  47.1689 -79.7346  0.086636  2024
# 139498           thessalon 2024-12-31  46.4957 -83.7170  0.260759  2024
# 139499         thunder bay 2024-12-31  49.1197 -88.4047  0.033853  2024
# 139500             timmins 2024-12-31  49.1549 -81.2948  0.055960  2024
# 139501           tobermory 2024-12-31  45.6419 -81.7172  0.211195  2024
#
#               time  precipitation_sum (mm)  rain_sum (mm)  snowfall_sum (cm)  \
# 0       2017-01-01                     2.8            0.0               1.96
# 1       2017-01-01                     0.9            0.0               0.63
# 2       2017-01-01                     1.9            0.0               1.33
# 3       2017-01-01                     0.0            0.0               0.00
# 4       2017-01-01                     1.8            0.2               1.12
# ...            ...                     ...            ...                ...
# 139497  2024-12-31                     0.7            0.1               0.42
# 139498  2024-12-31                     0.0            0.0               0.00
# 139499  2024-12-31                     0.0            0.0               0.00
# 139500  2024-12-31                     0.2            0.0               0.14
# 139501  2024-12-31                     0.0            0.0               0.00
#
#         ...  FIRE_OUT_DATE  FIRE_FINAL_SIZE  BUSINESS_EFFECTIVE_DATE  \
# 0       ...            NaN              NaN                      NaN
# 1       ...            NaN              NaN                      NaN
# 2       ...            NaN              NaN                      NaN
# 3       ...            NaN              NaN                      NaN
# 4       ...            NaN              NaN                      NaN
# ...     ...            ...              ...                      ...
# 139497  ...            NaN              NaN                      NaN
# 139498  ...            NaN              NaN                      NaN
# 139499  ...            NaN              NaN                      NaN
# 139500  ...            NaN              NaN                      NaN
# 139501  ...            NaN              NaN                      NaN
#
#         GEOMETRY_UPDATE_DATETIME  EFFECTIVE_DATETIME  SYSTEM_DATETIME  \
# 0                            NaN                 NaN              NaN
# 1                            NaN                 NaN              NaN
# 2                            NaN                 NaN              NaN
# 3                            NaN                 NaN              NaN
# 4                            NaN                 NaN              NaN
# ...                          ...                 ...              ...
# 139497                       NaN                 NaN              NaN
# 139498                       NaN                 NaN              NaN
# 139499                       NaN                 NaN              NaN
# 139500                       NaN                 NaN              NaN
# 139501                       NaN                 NaN              NaN
#
#         OBJECTID  longitude_right  latitude_right     _merge
# 0            NaN              NaN             NaN  left_only
# 1            NaN              NaN             NaN  left_only
# 2            NaN              NaN             NaN  left_only
# 3            NaN              NaN             NaN  left_only
# 4            NaN              NaN             NaN  left_only
# ...          ...              ...             ...        ...
# 139497       NaN              NaN             NaN  left_only
# 139498       NaN              NaN             NaN  left_only
# 139499       NaN              NaN             NaN  left_only
# 139500       NaN              NaN             NaN  left_only
# 139501       NaN              NaN             NaN  left_only
#
# [139502 rows x 49 columns]

# %%
final_merged['_merge'].value_counts()
# Out:
# _merge
# left_only     134160
# both            5342
# right_only         0
# Name: count, dtype: int64

# %%
final_merged.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139502 entries, 0 to 139501
# Data columns (total 49 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   city                               139502 non-null  object
#  1   date                               139502 non-null  datetime64[ns]
#  2   lat                                139502 non-null  float64
#  3   lon                                139502 non-null  float64
#  4   pm25                               139502 non-null  float64
#  5   year                               139502 non-null  int64
#  6   time                               139502 non-null  object
#  7   precipitation_sum (mm)             139502 non-null  float64
#  8   rain_sum (mm)                      139502 non-null  float64
#  9   snowfall_sum (cm)                  139502 non-null  float64
#  10  relative_humidity_2m_mean (%)      139502 non-null  float64
#  11  relative_humidity_2m_max (%)       139502 non-null  float64
#  12  relative_humidity_2m_min (%)       139502 non-null  float64
#  13  dew_point_2m_mean (°C)             139502 non-null  float64
#  14  shortwave_radiation_sum (MJ/m²)    139502 non-null  float64
#  15  sunshine_duration (s)              139502 non-null  float64
#  16  temperature_2m_mean (°C)           139502 non-null  float64
#  17  temperature_2m_max (°C)            139502 non-null  float64
#  18  temperature_2m_min (°C)            139502 non-null  float64
#  19  wind_speed_10m_mean (km/h)         139502 non-null  float64
#  20  wind_speed_10m_max (km/h)          139502 non-null  float64
#  21  winddirection_10m_dominant (°)     139502 non-null  float64
#  22  vapour_pressure_deficit_max (kPa)  139502 non-null  float64
#  23  et0_fao_evapotranspiration (mm)    139502 non-null  float64
#  24  City                               139502 non-null  object
#  25  longitude_left                     5342 non-null    float64
#  26  latitude_left                      5342 non-null    float64
#  27  Province                           5342 non-null    object
#  28  City / Town                        5342 non-null    object
#  29  geometry                           5342 non-null    geometry
#  30  index_right                        5342 non-null    float64
#  31  OGF_ID                             5342 non-null    float64
#  32  FIRE_DISTURBANCE_AREA_IDENT        5342 non-null    object
#  33  FIRE_TYPE_CODE                     5342 non-null    object
#  34  FIRE_YEAR                          5342 non-null    float64
#  35  FIRE_GENERAL_CAUSE_CODE            5333 non-null    object
#  36  FIRE_WEATHER_INDEX                 5342 non-null    float64
#  37  FIRE_RESPONSE_OBJ_CODE             5337 non-null    object
#  38  FIRE_START_DATE                    5342 non-null    object
#  39  FIRE_OUT_DATE                      5342 non-null    object
#  40  FIRE_FINAL_SIZE                    5342 non-null    float64
#  41  BUSINESS_EFFECTIVE_DATE            4256 non-null    object
#  42  GEOMETRY_UPDATE_DATETIME           5342 non-null    object
#  43  EFFECTIVE_DATETIME                 5342 non-null    object
#  44  SYSTEM_DATETIME                    5342 non-null    object
#  45  OBJECTID                           5342 non-null    float64
#  46  longitude_right                    5342 non-null    float64
#  47  latitude_right                     5342 non-null    float64
#  48  _merge                             139502 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(30), geometry(1), int64(1), object(15)
# memory usage: 51.2+ MB

# %%
final_merged[final_merged['FIRE_FINAL_SIZE']==1][:2].T
# Out:
#                                                                          4887  \
# city                                                              thunder bay
# date                                                      2017-04-14 00:00:00
# lat                                                                   49.1197
# lon                                                                  -88.4047
# pm25                                                                 1.995694
# year                                                                     2017
# time                                                               2017-04-14
# precipitation_sum (mm)                                                    0.0
# rain_sum (mm)                                                             0.0
# snowfall_sum (cm)                                                         0.0
# relative_humidity_2m_mean (%)                                            82.0
# relative_humidity_2m_max (%)                                             99.0
# relative_humidity_2m_min (%)                                             56.0
# dew_point_2m_mean (°C)                                                    0.4
# shortwave_radiation_sum (MJ/m²)                                         22.81
# sunshine_duration (s)                                                43551.86
# temperature_2m_mean (°C)                                                  3.6
# temperature_2m_max (°C)                                                   9.6
# temperature_2m_min (°C)                                                  -1.3
# wind_speed_10m_mean (km/h)                                                8.8
# wind_speed_10m_max (km/h)                                                15.9
# winddirection_10m_dominant (°)                                           80.0
# vapour_pressure_deficit_max (kPa)                                        0.52
# et0_fao_evapotranspiration (mm)                                          2.45
# City                                                              Thunder Bay
# longitude_left                                                       -89.9707
# latitude_left                                                          48.868
# Province                                                              Ontario
# City / Town                                                       Thunder Bay
# geometry                           POINT (6339148.35122846 1416378.761446469)
# index_right                                                           56538.0
# OGF_ID                                                            121438952.0
# FIRE_DISTURBANCE_AREA_IDENT                                              THU1
# FIRE_TYPE_CODE                                                            IFR
# FIRE_YEAR                                                              2017.0
# FIRE_GENERAL_CAUSE_CODE                                                   RWY
# FIRE_WEATHER_INDEX                                                       10.5
# FIRE_RESPONSE_OBJ_CODE                                                    FUL
# FIRE_START_DATE                                                    2017-04-14
# FIRE_OUT_DATE                                                      2017-04-15
# FIRE_FINAL_SIZE                                                           1.0
# BUSINESS_EFFECTIVE_DATE                                                   NaN
# GEOMETRY_UPDATE_DATETIME                               2018/02/28 13:01:32+00
# EFFECTIVE_DATETIME                                     2018/02/28 10:47:31+00
# SYSTEM_DATETIME                                        2018/02/28 22:07:15+00
# OBJECTID                                                             764817.0
# longitude_right                                                      -89.9707
# latitude_right                                                         48.868
# _merge                                                                   both
#
#                                                                            5926
# city                                                                   atikokan
# date                                                        2017-05-07 00:00:00
# lat                                                                     51.2216
# lon                                                                    -90.2304
# pm25                                                                   0.698778
# year                                                                       2017
# time                                                                 2017-05-07
# precipitation_sum (mm)                                                      0.0
# rain_sum (mm)                                                               0.0
# snowfall_sum (cm)                                                           0.0
# relative_humidity_2m_mean (%)                                              50.0
# relative_humidity_2m_max (%)                                               76.0
# relative_humidity_2m_min (%)                                               25.0
# dew_point_2m_mean (°C)                                                     -6.2
# shortwave_radiation_sum (MJ/m²)                                            28.2
# sunshine_duration (s)                                                  49612.93
# temperature_2m_mean (°C)                                                    4.5
# temperature_2m_max (°C)                                                    11.1
# temperature_2m_min (°C)                                                    -2.5
# wind_speed_10m_mean (km/h)                                                 10.2
# wind_speed_10m_max (km/h)                                                  13.4
# winddirection_10m_dominant (°)                                             38.0
# vapour_pressure_deficit_max (kPa)                                          0.99
# et0_fao_evapotranspiration (mm)                                            3.74
# City                                                                   Atikokan
# longitude_left                                                         -90.2343
# latitude_left                                                           51.2106
# Province                                                                Ontario
# City / Town                                                            Atikokan
# geometry                           POINT (6313146.198113772 1675322.2732358617)
# index_right                                                             56203.0
# OGF_ID                                                              121438967.0
# FIRE_DISTURBANCE_AREA_IDENT                                                SLK1
# FIRE_TYPE_CODE                                                              IFR
# FIRE_YEAR                                                                2017.0
# FIRE_GENERAL_CAUSE_CODE                                                     MIS
# FIRE_WEATHER_INDEX                                                          4.5
# FIRE_RESPONSE_OBJ_CODE                                                      FUL
# FIRE_START_DATE                                                      2017-05-07
# FIRE_OUT_DATE                                                        2017-05-07
# FIRE_FINAL_SIZE                                                             1.0
# BUSINESS_EFFECTIVE_DATE                                                     NaN
# GEOMETRY_UPDATE_DATETIME                                 2018/02/28 13:01:32+00
# EFFECTIVE_DATETIME                                       2018/02/28 10:47:33+00
# SYSTEM_DATETIME                                          2018/02/28 22:07:15+00
# OBJECTID                                                               759457.0
# longitude_right                                                        -90.2343
# latitude_right                                                          51.2106
# _merge                                                                     both

# %%
final_merged['City / Town'].value_counts().shape
# Out:
# (47,)

# %%
final_merged['City'].value_counts().shape
# Out:
# (47,)

# %%
cols_to_drop=['Province', 'City', 'City / Town', 'longitude_left', 'latitude_left', 'longitude_right', 'latitude_right', 'OBJECTID','time',
            'FIRE_DISTURBANCE_AREA_IDENT','BUSINESS_EFFECTIVE_DATE', 'GEOMETRY_UPDATE_DATETIME','EFFECTIVE_DATETIME', 'SYSTEM_DATETIME','_merge']

# %%
final_merged.drop(cols_to_drop,axis=1,inplace=True)

# %%
final_merged
# Out:
#                       city       date      lat      lon      pm25  year  \
# 0                 arnprior 2017-01-01  45.2001 -76.5278  2.090151  2017
# 1                 atikokan 2017-01-01  51.2216 -90.2304  0.128585  2017
# 2                 bancroft 2017-01-01  45.5890 -78.3437  2.089787  2017
# 3               belleville 2017-01-01  44.4855 -77.4459  4.860390  2017
# 4              bracebridge 2017-01-01  45.1669 -79.2325  6.356419  2017
# ...                    ...        ...      ...      ...       ...   ...
# 139497  temiskaming shores 2024-12-31  47.1689 -79.7346  0.086636  2024
# 139498           thessalon 2024-12-31  46.4957 -83.7170  0.260759  2024
# 139499         thunder bay 2024-12-31  49.1197 -88.4047  0.033853  2024
# 139500             timmins 2024-12-31  49.1549 -81.2948  0.055960  2024
# 139501           tobermory 2024-12-31  45.6419 -81.7172  0.211195  2024
#
#         precipitation_sum (mm)  rain_sum (mm)  snowfall_sum (cm)  \
# 0                          2.8            0.0               1.96
# 1                          0.9            0.0               0.63
# 2                          1.9            0.0               1.33
# 3                          0.0            0.0               0.00
# 4                          1.8            0.2               1.12
# ...                        ...            ...                ...
# 139497                     0.7            0.1               0.42
# 139498                     0.0            0.0               0.00
# 139499                     0.0            0.0               0.00
# 139500                     0.2            0.0               0.14
# 139501                     0.0            0.0               0.00
#
#         relative_humidity_2m_mean (%)  ...  index_right  OGF_ID  \
# 0                                80.0  ...          NaN     NaN
# 1                                82.0  ...          NaN     NaN
# 2                                82.0  ...          NaN     NaN
# 3                                76.0  ...          NaN     NaN
# 4                                84.0  ...          NaN     NaN
# ...                               ...  ...          ...     ...
# 139497                           86.0  ...          NaN     NaN
# 139498                           84.0  ...          NaN     NaN
# 139499                           78.0  ...          NaN     NaN
# 139500                           87.0  ...          NaN     NaN
# 139501                           80.0  ...          NaN     NaN
#
#         FIRE_TYPE_CODE  FIRE_YEAR  FIRE_GENERAL_CAUSE_CODE  \
# 0                  NaN        NaN                      NaN
# 1                  NaN        NaN                      NaN
# 2                  NaN        NaN                      NaN
# 3                  NaN        NaN                      NaN
# 4                  NaN        NaN                      NaN
# ...                ...        ...                      ...
# 139497             NaN        NaN                      NaN
# 139498             NaN        NaN                      NaN
# 139499             NaN        NaN                      NaN
# 139500             NaN        NaN                      NaN
# 139501             NaN        NaN                      NaN
#
#         FIRE_WEATHER_INDEX  FIRE_RESPONSE_OBJ_CODE  FIRE_START_DATE  \
# 0                      NaN                     NaN              NaN
# 1                      NaN                     NaN              NaN
# 2                      NaN                     NaN              NaN
# 3                      NaN                     NaN              NaN
# 4                      NaN                     NaN              NaN
# ...                    ...                     ...              ...
# 139497                 NaN                     NaN              NaN
# 139498                 NaN                     NaN              NaN
# 139499                 NaN                     NaN              NaN
# 139500                 NaN                     NaN              NaN
# 139501                 NaN                     NaN              NaN
#
#         FIRE_OUT_DATE  FIRE_FINAL_SIZE
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 139497            NaN              NaN
# 139498            NaN              NaN
# 139499            NaN              NaN
# 139500            NaN              NaN
# 139501            NaN              NaN
#
# [139502 rows x 34 columns]

# %%
final_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139502 entries, 0 to 139501
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   city                               139502 non-null  object
#  1   date                               139502 non-null  datetime64[ns]
#  2   lat                                139502 non-null  float64
#  3   lon                                139502 non-null  float64
#  4   pm25                               139502 non-null  float64
#  5   year                               139502 non-null  int64
#  6   precipitation_sum (mm)             139502 non-null  float64
#  7   rain_sum (mm)                      139502 non-null  float64
#  8   snowfall_sum (cm)                  139502 non-null  float64
#  9   relative_humidity_2m_mean (%)      139502 non-null  float64
#  10  relative_humidity_2m_max (%)       139502 non-null  float64
#  11  relative_humidity_2m_min (%)       139502 non-null  float64
#  12  dew_point_2m_mean (°C)             139502 non-null  float64
#  13  shortwave_radiation_sum (MJ/m²)    139502 non-null  float64
#  14  sunshine_duration (s)              139502 non-null  float64
#  15  temperature_2m_mean (°C)           139502 non-null  float64
#  16  temperature_2m_max (°C)            139502 non-null  float64
#  17  temperature_2m_min (°C)            139502 non-null  float64
#  18  wind_speed_10m_mean (km/h)         139502 non-null  float64
#  19  wind_speed_10m_max (km/h)          139502 non-null  float64
#  20  winddirection_10m_dominant (°)     139502 non-null  float64
#  21  vapour_pressure_deficit_max (kPa)  139502 non-null  float64
#  22  et0_fao_evapotranspiration (mm)    139502 non-null  float64
#  23  geometry                           5342 non-null    geometry
#  24  index_right                        5342 non-null    float64
#  25  OGF_ID                             5342 non-null    float64
#  26  FIRE_TYPE_CODE                     5342 non-null    object
#  27  FIRE_YEAR                          5342 non-null    float64
#  28  FIRE_GENERAL_CAUSE_CODE            5333 non-null    object
#  29  FIRE_WEATHER_INDEX                 5342 non-null    float64
#  30  FIRE_RESPONSE_OBJ_CODE             5337 non-null    object
#  31  FIRE_START_DATE                    5342 non-null    object
#  32  FIRE_OUT_DATE                      5342 non-null    object
#  33  FIRE_FINAL_SIZE                    5342 non-null    float64
# dtypes: datetime64[ns](1), float64(25), geometry(1), int64(1), object(6)
# memory usage: 36.2+ MB

# %%
final_merged[['date','city']].duplicated().sum()
# Out:
# np.int64(2168)

# %%
final_merged.to_csv('ontario_wildfire_weather_pm_2017_2024_2.csv',index=False)
